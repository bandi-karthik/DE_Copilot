# %%
import boto3

# %%
s3_client = boto3.client('s3')

s3_client.upload_file('employees_transform.txt',Bucket='de-copilot-s3',Key='transformations/employees_transform.txt')

# %%
s3_client = boto3.client('s3')

s3_client.upload_file('employees.csv',Bucket='de-copilot-s3',Key='data/incoming/employees.csv')

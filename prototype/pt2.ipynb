# %%
import json
from google import genai
from google.genai import types

# %%
client = genai.Client()

# %%
mock_ddl = {
    "table_name": "country",
    "database": "analytics_db",
    "layer": "raw",
    "purpose": "Master list of countries and their demographics.",
    
    "schema": [
        { "name": "Code", "type": "string", "nullable": False },
        { "name": "Name", "type": "string", "nullable": False },
        { "name": "Continent", "type": "string", "nullable": True },
        { "name": "Population", "type": "int", "nullable": True },
        { "name": "SurfaceArea", "type": "float", "nullable": True },
        { "name": "IndepYear", "type": "int", "nullable": True }
    ],
    "row_count": 239,
    "column_stats": {
        "Continent": {
            "null_pct": 0.0,
            "distinct_count": 7,
            "top_values": [
                 {"value": "Asia", "count": 51},
                 {"value": "Africa", "count": 58},
                 {"value": "Europe", "count": 46},
                 {"value": "North America", "count": 37},
                 {"value": "South America", "count": 14},
                 {"value": "Oceania", "count": 28},
                 {"value": "Antarctica", "count": 5}
            ]
        },
        "Population": {
             "min": 0,
             "max": 1400000000,
             "p95": 50000000
        },
        "IndepYear": {
            "min": 870,
            "max": 2023, 
            "null_pct": 0.15 
        }
    },
    
    "job_summary": {
        "job_name": "ingest_country_reference",
        "inputs": ["s3_raw_csv"],
        "filters": ["exclude where Code is null"]
    }
}

# %%
payload = f"""
You are a Senior Data Engineer Copilot. 
I will provide you with a JSON context object describing a data table.
Your goal is to generate a Data Quality Contract that balances **Strictness** (for clean data) with **Flexibility** (to avoid false alarms).
### INPUT CONTEXT:
{json.dumps(mock_ddl, indent=2)}

### INSTRUCTIONS:
Please note that the below instructions are only a guide and you can deviate from them if you see fit and if it is a necessary data quality check or 
# a necessary post load test. and keep the rules and test together if they belong to the same table in the respective JSON object.
# Think longer and more carefully before generating the rules and tests and make sure to cover all the necessary checks and you are not missing any edge cases at all.
# post generating the rules and tests, review your own rules. Did you miss any security checks (PII)? Did you miss any logical consistency checks? If so, add them.

1. **Analyze Schema & Logic (Hard Rules):**
   - Columns marked `nullable: False` must have `not_null` checks.
   - **CRITICAL**: For String columns that are `nullable: False`, ALSO check that they are not empty strings or whitespace only.
   - Numeric columns (Population, SurfaceArea) must generally be >= 0.
   - **Severity:** "ERROR" (Fundamental data issues).
   - **Action:** "FAIL_JOB" (if critical) or "DROP_ROW".
2. **Analyze Patterns & Types (Pattern Rules):**
   - Look at column names. If they imply a standard format (e.g., "Code", "Email", "IP", "UUID"), generate a `regex` rule.
   - Example: "Code" usually implies a fixed length or specific character set (e.g., ISO 3-letter code).
3. **Analyze Stats (Soft Rules & Buffers):**
   - Use `column_stats` to define expected ranges, BUT apply a **20% Buffer** to handle Data Drift.
   - If `distinct_count` is low (< 20) and stable (like Continent), create an `allowed_values` list.
   - **Severity:** "WARNING".
   - **Action:** "WARN".
4. **Cross-Column & Advanced Logic:**
   - Look for relationships. Does one column's value depend on another? (e.g., "If `IndepYear` is not null, `GovernmentForm` should not be 'Colony'").
   - If no obvious cross-column logic exists, skip this.
5. **Post-Load Tests (The Safety Net):**
   - Generate SQL tests for:
     - **Uniqueness**: Check Primary Keys (or composite keys) for duplicates.
     - **Completeness**: Row count > 0.
     - **Freshness/Future**: Ensure dates (like `IndepYear`) are not in the future relative to `CURRENT_DATE` (avoid hardcoded years).
   - These run AFTER the load.
6. **Output Format:**
   Return ONLY valid JSON in this structure:
   {{
      "data_quality": {{
          "rules": [
              {{ 
                "column": "col_name", 
                "rule_type": "not_null|not_empty|min|max|allowed_values|regex|custom_sql", 
                "condition": "value or list or sql_expression", 
                "severity": "ERROR|WARNING",
                "action": "DROP_ROW|FAIL_JOB|WARN",
                "description": "Reasoning..."
              }}
          ]
      }},
      "tests": [
          {{ "name": "test_name", "sql": "SELECT ...", "description": "..." }}
      ],
      "docs_markdown": "# Table Documentation..."
   }}
"""

# %%
response = client.models.generate_content(model='gemini-2.5-pro', contents=payload, 
config=types.GenerateContentConfig(response_mime_type="application/json" ))

# %%
print(response.text)
# Out:
# {
#   "data_quality": {
#     "rules": [
#       {
#         "column": "Code",
#         "rule_type": "pk",
#         "condition": null,
#         "severity": "ERROR",
#         "action": "FAIL_JOB",
#         "description": "Column Code is the primary key and must be unique for each country."
#       },
#       {
#         "column": "Code",
#         "rule_type": "not_null",
#         "condition": null,
#         "severity": "ERROR",
#         "action": "FAIL_JOB",
#         "description": "Country code must not be null."
#       },
#       {
#         "column": "Code",
#         "rule_type": "not_empty",
#         "condition": null,
#         "severity": "ERROR",
#         "action": "DROP_ROW",
#         "description": "Country code must not be an empty or whitespace-only string."
#       },
#       {
#         "column": "Code",
#         "rule_type": "regex",
#         "condition": "^[A-Z]{3}$",
#         "severity": "ERROR",
#         "action": "DROP_ROW",
#         "description": "Country code must be a 3-letter uppercase ISO code."
#       },
#       {
#         "column": "Name",
#         "rule_type": "not_null",
#         "condition": null,
#         "severity": "ERROR",
#         "action": "FAIL_JOB",
#         "description": "Country name must not be null."
#       },
#       {
#         "column": "Name",
#         "rule_type": "not_empty",
#         "condition": null,
#         "severity": "ERROR",
#         "action": "DROP_ROW",
#         "description": "Country name must not be an empty or whitespace-only string."
#       },
#       {
#         "column": "Continent",
#         "rule_type": "allowed_values",
#         "condition": [
#           "Asia",
#           "Africa",
#           "Europe",
#           "North America",
#           "South America",
#           "Oceania",
#           "Antarctica"
#         ],
#         "severity": "ERROR",
#         "action": "DROP_ROW",
#         "description": "Continent must be one of the seven recognized continents. Nulls are allowed."
#       },
#       {
#         "column": "Population",
#         "rule_type": "check_constraint",
#         "condition": "Population >= 0",
#         "severity": "ERROR",
#         "action": "DROP_ROW",
#         "description": "Population cannot be negative. This enforces the table's check constraint."
#       },
#       {
#         "column": "Population",
#         "rule_type": "max",
#         "condition": 1700000000,
#         "severity": "WARNING",
#         "action": "WARN",
#         "description": "Population should not exceed 1.7 billion. This is a soft check for data entry errors, based on a 20% buffer over the observed maximum."
#       },
#       {
#         "column": "SurfaceArea",
#         "rule_type": "check_constraint",
#         "condition": "SurfaceArea > 0",
#         "severity": "ERROR",
#         "action": "DROP_ROW",
#         "description": "Surface area must be a positive value if it is not null."
#       },
#       {
#         "column": "IndepYear",
#         "rule_type": "check_constraint",
#         "condition": "IndepYear <= YEAR(CURRENT_DATE())",
#         "severity": "ERROR",
#         "action": "DROP_ROW",
#         "description": "Independence year cannot be in the future."
#       },
#       {
#         "column": "IndepYear",
#         "rule_type": "min",
#         "condition": 800,
#         "severity": "WARNING",
#         "action": "WARN",
#         "description": "Independence year should not be before 800 AD. This is a soft check for data entry errors."
#       }
#     ]
#   },
#   "tests": [
#     {
#       "name": "test_table_has_rows",
#       "sql": "SELECT 1 FROM analytics_db.raw.country HAVING COUNT(*) = 0",
#       "description": "Fails if the country table is empty after loading."
#     },
#     {
#       "name": "test_pk_uniqueness_country_code",
#       "sql": "SELECT Code FROM analytics_db.raw.country GROUP BY Code HAVING COUNT(*) > 1",
#       "description": "Ensures that every country Code is unique."
#     },
#     {
#       "name": "test_code_not_null_or_empty",
#       "sql": "SELECT Code FROM analytics_db.raw.country WHERE Code IS NULL OR TRIM(Code) = ''",
#       "description": "Verifies that the primary key column 'Code' contains no null or empty values."
#     },
#     {
#       "name": "test_name_not_null_or_empty",
#       "sql": "SELECT Name FROM analytics_db.raw.country WHERE Name IS NULL OR TRIM(Name) = ''",
#       "description": "Verifies that the 'Name' column contains no null or empty values."
#     },
#     {
#       "name": "test_population_non_negative",
#       "sql": "SELECT Population FROM analytics_db.raw.country WHERE Population < 0",
#       "description": "Checks for any records with a negative population value, enforcing the 'chk_population_non_negative' constraint."
#     },
#     {
#       "name": "test_surfacearea_positive",
#       "sql": "SELECT SurfaceArea FROM analytics_db.raw.country WHERE SurfaceArea IS NOT NULL AND SurfaceArea <= 0",
#       "description": "Checks for any records with a non-positive surface area, enforcing the 'chk_surfacearea_positive' constraint."
#     },
#     {
#       "name": "test_continent_allowed_values",
#       "sql": "SELECT DISTINCT Continent FROM analytics_db.raw.country WHERE Continent IS NOT NULL AND Continent NOT IN ('Asia', 'Africa', 'Europe', 'North America', 'South America', 'Oceania', 'Antarctica')",
#       "description": "Ensures the Continent column only contains values from the expected list."
#     },
#     {
#       "name": "test_indepyear_not_in_future",
#       "sql": "SELECT IndepYear FROM analytics_db.raw.country WHERE IndepYear > YEAR(CURRENT_DATE())",
#       "description": "Ensures no independence years are recorded in the future."
#     }
#   ],
#   "docs_markdown": "# Table: analytics_db.raw.country\n\n**Purpose:** This table serves as a master list of countries and their key demographic and geographic information.\n\n**Grain:** Each record represents a single country, uniquely identified by its `Code`.\n\n## Columns\n\n| Column      | Type    | Nullable | Description                                                                 |\n|-------------|---------|----------|-----------------------------------------------------------------------------|\n| Code        | string  | false    | The unique 3-letter ISO code for the country. This is the primary key.      |\n| Name        | string  | false    | The common name of the country.                                             |\n| Continent   | string  | true     | The continent where the country is located.                                 |\n| Population  | int     | true     | The estimated population of the country.                                    |\n| SurfaceArea | float   | true     | The total surface area of the country in square kilometers.                 |\n| IndepYear   | int     | true     | The year the country gained independence. Null if not applicable or unknown.|\n\n## Data Quality Rules\n\nThis table has several data quality rules enforced to ensure its reliability:\n\n- **Primary Key:** The `Code` column is the primary key and must be unique and not null.\n- **Validity Checks:**\n  - `Population` must be a non-negative number (`>= 0`).\n  - `SurfaceArea` must be a positive number (`> 0`) if provided.\n  - `Continent` must be one of the seven official continents.\n  - `IndepYear` cannot be a year in the future.\n- **Completeness:** `Code` and `Name` fields must not be empty or null.\n"
# }
